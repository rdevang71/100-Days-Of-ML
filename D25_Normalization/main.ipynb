# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['class label','alcohol','malic acid']
df
# Out:
#      class label  alcohol  malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
color_dict={1:'red',2:'yellow',3:'green'}
sns.scatterplot(x='alcohol',y='malic acid',hue='class label', data=df, palette=color_dict)
# Out:
# <Axes: xlabel='alcohol', ylabel='malic acid'>

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(df.drop('class label',axis=1),df['class label'],test_size=0.1,random_state=12)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train)

X_test_scaled = scaler.transform(X_test)
X_train_scaled = scaler.transform(X_train)

X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)

# %%
X_train_scaled.describe()
# Out:
#           alcohol  malic acid
# count  160.000000  160.000000
# mean     0.516694    0.300099
# std      0.214300    0.214265
# min      0.000000    0.000000
# 25%      0.350658    0.156126
# 50%      0.528947    0.211462
# 75%      0.695395    0.416008
# max      1.000000    1.000000

# %%
sns.scatterplot(x='alcohol',y= 'malic acid',data=X_train_scaled,hue=y_train,palette=color_dict)
# Out:
# <Axes: xlabel='alcohol', ylabel='malic acid'>
